# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd

# %%
df = pd.read_excel('./export_valores_mensais.xlsx')
df
# Out:
#                                       PAÍS  EXPORTAÇÃO (JAN - JUN/2020)  \
# 0                              Total Geral                 101719578613
# 1                                    China                  34351112105
# 2                           Estados Unidos                  10048062241
# 3                  Países Baixos (Holanda)                   4223097367
# 4                                Argentina                   3695105886
# ..                                     ...                          ...
# 244                        Saara Ocidental                            0
# 245                   Svalbard e Jan Mayen                            0
# 246                           Tadjiquistão                            0
# 247  Território Britânico do Oceano Índico                            0
# 248                               Toquelau                            0
#
#      EXPORTAÇÃO (JAN/JUN2019)  IMPORTAÇÃO (JAN/JUN2020)  \
# ...

# %%
df1 = pd.read_excel('./export_junho_bal_comercial.xlsx')
df1
# Out:
#      ANO  EXPORTAÇÃO (A)  IMPORTAÇÃO (B)  SALDO(A-B)  CORRENTE (A+B)  \
# 0   2001      5037237666      4748374983   288862683      9785612649
# 1   2002      4074345872      3392528713   681817159      7466874585
# 2   2003      5870395443      3517400117  2352995326      9387795560
# 3   2004      9306641136      5523155106  3783486030     14829796242
# 4   2005     10225065341      6158080439  4066984902     16383145780
# 5   2006     11452428542      7352736030  4099692512     18805164572
# 6   2007     13112703159      9284865192  3827837967     22397568351
# 7   2008     18581634423     15882447756  2699186667     34464082179
# 8   2009     14460763044      9876841477  4583921567     24337604521
# 9   2010     17088559146     14828947481  2259611665     31917506627
# 10  2011     23683910083     19251134755  4432775328     42935044838
# 11  2012     19340965719     18555490041   785475678     37896455760
# 12  2013     21126804222     18830624180  2296180042     39957428402
# ...

# %%
df.dtypes
# Out:
# PAÍS                           object
# EXPORTAÇÃO (JAN - JUN/2020)     int64
# EXPORTAÇÃO (JAN/JUN2019)        int64
# IMPORTAÇÃO (JAN/JUN2020)        int64
# IMPORTAÇÃO (JAN/JUN2019)        int64
# SALDO(2020)                     int64
# SALDO(2019)                     int64
# CORRENTE (2020)                 int64
# CORRENTE (2019)                 int64
# dtype: object
